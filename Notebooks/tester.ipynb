# %%
import pandas as pd

# %%
import requests
from io import StringIO

with requests.get('https://fiapfunctionapp.azurewebsites.net/api/models') as _response:
    response = _response.content.decode('utf-8')
    _data = StringIO(response)
    df= pd.read_csv(_data)

# %%
df
# Out:
#       Unnamed: 0     model_type  estimators  accuracy   precision       mcc
# 0              0  random_forest         500     100.0  100.000000  0.000000  \
# 1              1  random_forest         500     100.0  100.000000  0.000000
# 2              2  random_forest         447      66.0    0.631050  0.684193
# 3              3  random_forest         455      37.0    0.125741  0.904308
# 4              4  random_forest         385      74.0    0.064132  0.553117
# ...          ...            ...         ...       ...         ...       ...
# 1675        1675  deep learning         500       1.0         NaN       NaN
# 1676        1676  deep learning         500       1.0         NaN       NaN
# 1677        1677  deep learning         500       1.0         NaN       NaN
# 1678        1678  deep learning         500       1.0         NaN       NaN
# 1679        1679  deep learning         500       1.0         NaN       NaN
#
# ...
